# %% [markdown]
# # what to generate...
# * add option to have some translations in native language...
# # website with html, java
# * toggle "include", insert file path --> insert file, host it as a website..
# ### add lisardo csv automatic instructions
#
# ... a system, where you can check every line, and regenerate if necessary...

# %%
# works with the csv export from the lln website

import pandas as pd
import re
from dotenv import load_dotenv
import os
import openai
import random

# chatGPT parameters

load_dotenv()
openai.api_key = os.getenv("22API_KEY")

max_tokens = 100
max_words = max_tokens * 0.3
print("maximum words:", max_words)
model = "gpt-4-1106-preview" # "gpt-3.5-turbo-16k # gpt-4-1106-preview # gpt-4-turbo # gpt-4-32k



# what should be generated by chatGPT?

native_language = "english"

# Check if the CSV file exists
csv_file_path = "/Users/moritzvitt/Downloads/df_gpt.csv"
if not os.path.exists(csv_file_path):
    # Create a new CSV file
    with open(csv_file_path, "w") as csv_file:
        # Write the header row
        csv_file.write("synonyms, hints, definition, explanation, native_language_definition, native_language_explanation")

df_gpt = pd.read_csv(csv_file_path, delimiter='\t')

print(df_gpt.columns)
#building the data frame
df = pd.read_csv('/Users/moritzvitt/downloads/anki/items.csv', delimiter='\t')


df.columns = df.iloc[0]
df = df.drop(df.iloc[:, [1, 7, 11, 12, 13, 14, 15]], axis=1)

df.columns = ["ID", "short_phrase", "short_translation", "word", "stem", "word_type", "word_translation", "website", "lang", "source", "date", "long_phrase", "machine_translation", "human_translation", "first_jpg", "second_jpg", "audio"]

print(df.columns)
print(df.head)
# Out:
# maximum words: 30.0
# Index(['synonyms, hints, definition, explanation, native_language_definition, native_language_explanation'], dtype='object')
# Index(['ID', 'short_phrase', 'short_translation', 'word', 'stem', 'word_type',
#        'word_translation', 'website', 'lang', 'source', 'date', 'long_phrase',
#        'machine_translation', 'human_translation', 'first_jpg', 'second_jpg',
#        'audio'],
#       dtype='object')
# <bound method NDFrame.head of                           ID  \
# 0         WORD|asapissimo|de
# 1          WORD|unterlage|de
# 2             WORD|brutto|de
# 3         WORD|verbeamten|de
# 4             WORD|gehalt|de
# 5        WORD|merkwürdige|de
# 6        WORD|inkompetent|de
# 7          WORD|turnhalle|de
# 8         WORD|kabelbrand|de
# 9       WORD|strafanzeige|de
# 10       WORD|herzinfarkt|de
# 11              WORD|fahl|de
# 12           WORD|kratzen|de
# 13             WORD|faust|de
# 14           WORD|beeilen|de
# 15           WORD|begeben|de
# 16        WORD|glühbirnen|de
# 17       WORD|mistviecher|de
# 18        WORD|bescheuert|de
# 19  WORD|schlankheitsfarm|de
# 20            WORD|pennen|de
# 21      WORD|vorgeschmack|de
# 22         WORD|schuldest|de
# 23           WORD|anheben|de
# 24          WORD|verlegen|de
# 25           WORD|glitter|de
# 26        WORD|arschritze|de
# 27        WORD|verarschen|de
# 28        WORD|übernimmst|de
# 29         WORD|ernsthaft|de
# 30               WORD|hup|de
# 31            WORD|fresse|de
# 32             WORD|titte|de
# 33             WORD|arsch|de
# 34          WORD|schulhof|de
# 35            WORD|gucken|de
# 36        WORD|stecknadel|de
# 37             WORD|kohle|de
# 38         WORD|vergraben|de
# 39         WORD|gelutsche|de
# 40               WORD|heb|de
# 41          WORD|freiheit|de
# 42  WORD|allgemeinbildung|de
# 43             WORD|farce|de
# 44           WORD|verpiss|de
# 45              WORD|nenn|de
# 46           WORD|wiehert|de
# 47            WORD|reiten|de
# 48            WORD|pimmel|de
# 49     WORD|seitenstechen|de
# 50  WORD|lebensverändernd|de
# 51       WORD|beuteschema|de
# 52           WORD|brüsten|de
# 53       WORD|hosentasche|de
# 54       WORD|gesamtwisse|de
# 55         WORD|verzerren|de
# 56              WORD|okay|de
# 57              WORD|auch|de
# 58          WORD|schlecht|de
#
#                                          short_phrase  \
# 0           Wir sehen uns asapissimo im Lehrerzimmer.
# 1           Deal. - Ihre Unterlagen reichen Sie nach.
# 2   Nee, nicht so. - Ich biete Ihnen 2.000 Euro Br...
# 3   Gehalt ist immer gut. - Sie sind nicht verbeam...
# 4                                             Gehalt?
# 5   Bekomme ich einen Universalschlüssel? - Merkwü...
# 6   Die neue Turnhalle habe ich skizziert. Der Arc...
# 7     Und dann der Kabelbrand in der alten Turnhalle.
# 8     Und dann der Kabelbrand in der alten Turnhalle.
# 9   Mein Budget geht ja drauf für die Verwaltung d...
# 10  Der Hausmeister hatte einen Herzinfarkt. und w...
# 11  Wie, Aushilfslehrer? - Ich weiß, hat einen fah...
# 12  dass du dich von innen am Hals kratzen kannst,...
# 13    Ich steck dir deine Faust so tief in den Arsch,
# 14  Ey, ich hab einen Schuss gehört, beeilt euch mal!
# 15  (Durchsage) Amokalarm. Bitte begeben Sie sich ...
# 16  Können Sie denn Glühbirnen austauschen? Haben ...
# 17  Jetzt nicht, Frau Leimbach-Knorr. - Die Mistvi...
# 18                 Ist das nicht ziemlich bescheuert?
# 19  Bis Gina von der Schlankheitsfarm kommt. Dann ...
# 20  Alles klar. Weiß Bescheid. Kann ich so lange b...
# 21        Kleiner Vorgeschmack, wenn's länger dauert.
# 22  Du schuldest mir 2.000 Euro. Und 50 für den Gl...
# 23  Vielleicht kann man die ja noch anheben. Mit '...
# 24  Du vergräbst es auf 'ner Baustelle? - Ich dach...
# 25  Ich steh da nicht drauf. Tagelang der Glitter ...
# 26  Ich steh da nicht drauf. Tagelang der Glitter ...
# 27                 Sag mal, will die mich verarschen?
# 28               Übernimmst du heute meinen 54-Dance?
# 29      Ernsthaft jetzt. Kann ich das Radio anmachen?
# 30        Fresse. Drück auf die Hupe, wenn wer kommt.
# 31        Fresse. Drück auf die Hupe, wenn wer kommt.
# 32      Du, Zeki, krieg ich von dem Geld neue Titten?
# 33    Ich dachte, auf 'nem Schulhof guckt kein Arsch.
# 34    Ich dachte, auf 'nem Schulhof guckt kein Arsch.
# 35    Ich dachte, auf 'nem Schulhof guckt kein Arsch.
# 36     Hier sind die Koordinaten, bei der Stecknadel.
# 37             Wo ist die Kohle? - Hab ich vergraben.
# 38             Wo ist die Kohle? - Hab ich vergraben.
# 39  Komm, heb dir das Gelutsche für deine Kundscha...
# 40  Komm, heb dir das Gelutsche für deine Kundscha...
# 41                                          Freiheit!
# 42  Obwohl Sie mit so wenig Allgemeinbildung eine ...
# 43          Herr Müller, Ihre Prüfung war eine Farce.
# 44                          -Verpiss dich. -Ja, okay.
# 45  Nenn mir einen Grund, warum ich dir was verkau...
# 46                               [Ein Pferd wiehert.]
# 47             -Na ja, der geht hier reiten. -Reiten?
# 48  -[Junge] Was 'ne Pussy! -Ey, kümmer du dich um...
# 49                        -Seitenstechen! -Arme hoch.
# 50                     Lebensverändernde Erfahrungen.
# 51  Groß, gut aussehend, beliebt. Gar nicht ihr Be...
# 52            Der Bruder von Melanie mit den Brüsten.
# 53  Jeder von uns hat das Gesamtwissen der Menschh...
# 54  Jeder von uns hat das Gesamtwissen der Menschh...
# 55                       [Song geht verzerrt weiter.]
# 56                           [Moritz] Ist alles okay?
# 57           -Warte. -Darf ich hier auch reinschauen?
# 58  Moritz, die Verbindung ist schlecht. Wollen wi...
#
#                                     short_translation               word  \
# 0               See you asapissimo in the staff room.         asapissimo
# 1                      Deal. - Submit your documents.         Unterlagen
# 2   No, not like that. - I offer you 2,000 euros g...             Brutto
# 3   Salary is always good. - You are not a civil s...         verbeamtet
# 4                                             Salary?             Gehalt
# 5   Can I get a universal key? - Strange question,...        Merkwürdige
# 6   I sketched the new gym. The architect was comp...        inkompetent
# 7             And then the cable fire in the old gym.          Turnhalle
# 8             And then the cable fire in the old gym.         Kabelbrand
# 9   My budget goes on the administration of crimin...      Strafanzeigen
# 10  The janitor had a heart attack. and we do not ...        Herzinfarkt
# 11  What, substitute teacher? - I know, has a pale...             fahlen
# 12  that you can scratch your neck from the inside...            kratzen
# 13          I'll stick your fist so deep in your ass,              Faust
# 14                     Hey, I heard a shot, hurry up!             beeilt
# 15  (Announcement) Amokalarm. Please go to a room ...            begeben
# 16         Can you replace bulbs? Did you do the job?         Glühbirnen
# 17  Not now, Mrs Leimbach-Knorr. - The dung critte...        Mistviecher
# 18                         Is not that pretty stupid?         bescheuert
# 19  Until Gina comes from the slimming farm. Then ...   Schlankheitsfarm
# 20  All right. Know. Can I stay with you for so long?             pennen
# 21                  Little taste, if it takes longer.       Vorgeschmack
# 22  you owe me 2,000 euros. and 50 for the glass t...          schuldest
# 23    Maybe you can raise that yet. With a ... crane?            anheben
# 24  You bury it on a construction site? - I though...           verlegen
# 25      I'm not into it. For days the glitter in the.            Glitter
# 26      I'm not into it. For days the glitter in the.         Arschritze
# 27                        Tell me, is she kidding me?         verarschen
# 28                     Do you take my 54-Dance today?         Übernimmst
# 29            Seriously now. Can I turn on the radio?          Ernsthaft
# 30                 Face. Hit the horn when who comes.               Hupe
# 31                 Face. Hit the horn when who comes.             Fresse
# 32       You, Zeki, do I get new tits from the money?             Titten
# 33         I thought, there's no ass on a schoolyard.              Arsch
# 34         I thought, there's no ass on a schoolyard.           Schulhof
# 35         I thought, there's no ass on a schoolyard.              guckt
# 36              Here are the coordinates, at the pin.         Stecknadel
# 37                  Where is the coal? - I buried it.              Kohle
# 38                  Where is the coal? - I buried it.          vergraben
# 39          Come, save the gossip for your clientele.          Gelutsche
# 40          Come, save the gossip for your clientele.                heb
# 41                                           Freedom!           Freiheit
# 42  Obwohl Sie mit so wenig Allgemeinbildung eine ...   Allgemeinbildung
# 43          Herr Müller, Ihre Prüfung war eine Farce.              Farce
# 44                      - Fuck you. - Yeah, I got it.            Verpiss
# 45  Give me a reason why I should sell you something.               Nenn
# 46                                [A horse whistles.]            wiehert
# 47    -Well, he's going horseback riding here. -Ride?             reiten
# 48  -[Boy] What a pussy! -Hey, take care of your pee!             Pimmel
# 49                                 -Stitch! -Arms up.      Seitenstechen
# 50                         Life-changing experiences.  Lebensverändernde
# 51                            高大，美觀，受歡迎。 不是她的戰利品計劃。右。        Beuteschema
# 52                                     Melanie的兄弟與乳房。            Brüsten
# 53                                  我們每個人都擁有口袋裡的人性知識。        Hosentasche
# 54                                  我們每個人都擁有口袋裡的人性知識。       Gesamtwissen
# 55                                           [宋繼續扭曲。]           verzerrt
# 56                                        [莫里茨]一切都好嗎？               okay
# 57                                 -Wait。  - 我也在這看看嗎？               auch
# 58                              莫里茨，連接不好。我們以後要不要和平交談？           schlecht
#
#                 stem word_type  \
# 0         asapissimo       Adv
# 1          Unterlage      Noun
# 2             Brutto     Propn
# 3         verbeamten      Verb
# 4             Gehalt      Verb
# 5        merkwürdige      Noun
# 6        inkompetent       Adj
# 7          Turnhalle      Noun
# 8         Kabelbrand      Noun
# 9       Strafanzeige      Noun
# 10       Herzinfarkt      Noun
# 11              fahl      Noun
# 12           kratzen      Verb
# 13             Faust      Noun
# 14           beeilen      Verb
# 15           begeben      Verb
# 16        Glühbirnen      Noun
# 17       Mistviecher      Noun
# 18        bescheuert      Verb
# 19  Schlankheitsfarm      Noun
# 20            pennen      Verb
# 21      Vorgeschmack      Noun
# 22         schuldest      Verb
# 23           anheben      Verb
# 24          verlegen      Verb
# 25           Glitter      Noun
# 26        Arschritze      Noun
# 27        verarschen      Verb
# 28        übernimmst       Adv
# 29         ernsthaft       Adj
# 30               hup      Noun
# 31            fresse      Noun
# 32             Titte      Noun
# 33             Arsch      Noun
# 34          Schulhof      Noun
# 35            gucken      Verb
# 36        Stecknadel      Noun
# 37             Kohle      Noun
# 38         vergraben      Verb
# 39         Gelutsche      Noun
# 40               heb       Adv
# 41          Freiheit      Noun
# 42  Allgemeinbildung      Noun
# 43             Farce      Noun
# 44           verpiss      Noun
# 45              nenn     Sconj
# 46           wiehert       Adv
# 47            reiten      Verb
# 48            pimmel      Noun
# 49     Seitenstechen      Noun
# 50  lebensverändernd       Adj
# 51       beuteschema      Noun
# 52           brüsten      Noun
# 53       hosentasche      Noun
# 54       Gesamtwisse      Noun
# 55         verzerren       Adj
# 56              okay     Propn
# 57              auch       Adv
# 58          schlecht       Adj
#
#                                      word_translation  website lang  \
# 0               Asapissimo, as soon as possible, ASAP  Netflix   de
# 1             documents, supporting documents, papers  Netflix   de
# 2                                        gross, brute  Netflix   de
# 3   civil servant, appointed as a civil servant, g...  Netflix   de
# 4                               salary, content, wage  Netflix   de
# 5                               strange, curious, odd  Netflix   de
# 6                incompetent, unqualified, inadequate  Netflix   de
# 7                         gym, gymnasium, sports hall  Netflix   de
# 8                           cable fire, short circuit  Netflix   de
# 9    complaint, criminal charges, criminal complaints  Netflix   de
# 10         heart attack, cardiac infarction, coronary  Netflix   de
# 11                               sallow, pale, pallid  Netflix   de
# 12                              scratch, scrape, claw  Netflix   de
# 13                                   fist, Faust, own  Netflix   de
# 14                           hurry, hurried, hastened  Netflix   de
# 15                  to embark, to undertake, to go on  Netflix   de
# 16             light bulbs, bulbs, incandescent bulbs  Netflix   de
# 17        damn animals, damn critters, damn creatures  Netflix   de
# 18                          stupid, ridiculous, crazy  Netflix   de
# 19              slimming farm, lean, weight loss farm  Netflix   de
# 20                            kip, to crash, to sleep  Netflix   de
# 21               foretaste, anticipation, premonition  Netflix   de
# 22                    owe, be indebted, be in debt to  Netflix   de
# 23                               raise, lift, lifting  Netflix   de
# 24                    embarrassed, transfer, misplace  Netflix   de
# 25                          glitter, sparkle, shimmer  Netflix   de
# 26                        ass crack, coat, butt crack  Netflix   de
# 27                         kidding, to fool, to trick  Netflix   de
# 28                       take over, assume, undertake  Netflix   de
# 29                      seriously, earnest, earnestly  Netflix   de
# 30                                  horn, hooter, HUP  Netflix   de
# 31                                mug, trap, cakehole  Netflix   de
# 32                               boobs, tits, breasts  Netflix   de
# 33                                     ass, butt, bum  Netflix   de
# 34                schoolyard, school yard, playground  Netflix   de
# 35                                 peek, peeks, peeps  Netflix   de
# 36                  pin, dressmaker's pin, sewing pin  Netflix   de
# 37                                 coal, cash, carbon  Netflix   de
# 38                             bury, buried, entombed  Netflix   de
# 39                          wing, sucking, slobbering  Netflix   de
# 40                               lift, raise, elevate  Netflix   de
# 41                          freedom, liberty, license  Netflix   de
# 42                                                NaN  Netflix   de
# 43                                                NaN  Netflix   de
# 44                           piss off, piss, fuck off  Netflix   de
# 45                                call, name, nominal  Netflix   de
# 46                            neighs, whinnies, neigh  Netflix   de
# 47              ride, to ride, to go horseback riding  Netflix   de
# 48                                 cock, pecker, dick  Netflix   de
# 49                              stitch, side piercing  Netflix   de
# 50                      life -changing, life-changing  Netflix   de
# 51                                       戰利品原理, 戰利品計劃  Netflix   de
# 52                                                 吹噓  Netflix   de
# 53                                                 口袋  Netflix   de
# 54                                          整體知識, 總知識  Netflix   de
# 55                                                 扭曲  Netflix   de
# 56                                          好吧, 好, 好的  Netflix   de
# 57                                           還, 也, 同樣  Netflix   de
# 58                                           壞, 不好, 差  Netflix   de
#
#                        source              date  \
# 0          Suck Me Shakespeer  2023-11-25 16:26
# 1          Suck Me Shakespeer  2023-11-25 16:26
# 2          Suck Me Shakespeer  2023-11-25 16:25
# 3          Suck Me Shakespeer  2023-11-25 16:25
# 4          Suck Me Shakespeer  2023-11-25 16:25
# 5          Suck Me Shakespeer  2023-11-25 16:25
# 6          Suck Me Shakespeer  2023-11-25 16:24
# 7          Suck Me Shakespeer  2023-11-25 16:24
# 8          Suck Me Shakespeer  2023-11-25 16:24
# 9          Suck Me Shakespeer  2023-11-25 16:24
# 10         Suck Me Shakespeer  2023-11-25 16:24
# 11         Suck Me Shakespeer  2023-11-25 16:23
# 12         Suck Me Shakespeer  2023-11-25 16:22
# 13         Suck Me Shakespeer  2023-11-25 16:22
# 14         Suck Me Shakespeer  2023-11-25 16:22
# 15         Suck Me Shakespeer  2023-11-25 16:21
# 16         Suck Me Shakespeer  2023-11-25 16:21
# 17         Suck Me Shakespeer  2023-11-25 16:20
# 18         Suck Me Shakespeer  2023-11-25 16:18
# 19         Suck Me Shakespeer  2023-11-25 16:16
# 20         Suck Me Shakespeer  2023-11-25 16:16
# 21         Suck Me Shakespeer  2023-11-25 16:15
# 22         Suck Me Shakespeer  2023-11-25 16:15
# 23         Suck Me Shakespeer  2023-11-25 16:14
# 24         Suck Me Shakespeer  2023-11-25 16:14
# 25         Suck Me Shakespeer  2023-11-25 16:14
# 26         Suck Me Shakespeer  2023-11-25 16:13
# 27         Suck Me Shakespeer  2023-11-25 16:13
# 28         Suck Me Shakespeer  2023-11-25 16:13
# 29         Suck Me Shakespeer  2023-11-25 16:12
# 30         Suck Me Shakespeer  2023-11-25 16:12
# 31         Suck Me Shakespeer  2023-11-25 16:12
# 32         Suck Me Shakespeer  2023-11-25 16:12
# 33         Suck Me Shakespeer  2023-11-25 16:11
# 34         Suck Me Shakespeer  2023-11-25 16:11
# 35         Suck Me Shakespeer  2023-11-25 16:11
# 36         Suck Me Shakespeer  2023-11-25 16:10
# 37         Suck Me Shakespeer  2023-11-25 16:10
# 38         Suck Me Shakespeer  2023-11-25 16:10
# 39         Suck Me Shakespeer  2023-11-25 16:09
# 40         Suck Me Shakespeer  2023-11-25 16:09
# 41         Suck Me Shakespeer  2023-11-25 16:08
# 42         Suck Me Shakespeer  2023-11-25 16:06
# 43         Suck Me Shakespeer  2023-11-25 16:05
# 44  全歐最酷線上藥頭 第 1 集： 今日阿宅，明日老大  2023-10-12 14:09
# 45  全歐最酷線上藥頭 第 1 集： 今日阿宅，明日老大  2023-10-12 14:09
# 46  全歐最酷線上藥頭 第 1 集： 今日阿宅，明日老大  2023-10-12 14:07
# 47  全歐最酷線上藥頭 第 1 集： 今日阿宅，明日老大  2023-10-12 14:04
# 48  全歐最酷線上藥頭 第 1 集： 今日阿宅，明日老大  2023-10-12 14:03
# 49  全歐最酷線上藥頭 第 1 集： 今日阿宅，明日老大  2023-10-12 14:02
# 50  全歐最酷線上藥頭 第 1 集： 今日阿宅，明日老大  2023-10-12 13:50
# 51  全歐最酷線上藥頭 第 1 集： 今日阿宅，明日老大  2023-10-12 13:48
# 52  全歐最酷線上藥頭 第 1 集： 今日阿宅，明日老大  2023-10-12 13:47
# 53  全歐最酷線上藥頭 第 1 集： 今日阿宅，明日老大  2023-10-12 13:40
# 54  全歐最酷線上藥頭 第 1 集： 今日阿宅，明日老大  2023-10-12 13:40
# 55  全歐最酷線上藥頭 第 1 集： 今日阿宅，明日老大  2023-10-12 13:38
# 56  全歐最酷線上藥頭 第 1 集： 今日阿宅，明日老大  2023-10-12 13:36
# 57  全歐最酷線上藥頭 第 1 集： 今日阿宅，明日老大  2023-10-12 13:36
# 58  全歐最酷線上藥頭 第 1 集： 今日阿宅，明日老大  2023-10-12 13:36
#
#                                           long_phrase  \
# 0   Deal. - Ihre Unterlagen reichen Sie nach.\nWir...
# 1   Na gut, 2.200. Aber höher wirklich nicht. Wir ...
# 2   Gehalt ist immer gut. - Sie sind nicht verbeam...
# 3   Gehalt?\nGehalt ist immer gut. - Sie sind nich...
# 4   Bekomme ich einen Universalschlüssel? - Merkwü...
# 5   Die neue Turnhalle habe ich skizziert. Der Arc...
# 6   Bis dahin müssen wir eben selber Hand anlegen....
# 7   Mein Budget geht ja drauf für die Verwaltung d...
# 8   Mein Budget geht ja drauf für die Verwaltung d...
# 9   Der Hausmeister hatte einen Herzinfarkt. und w...
# 10  Herr... - Müller. Zeki Müller.\nDer Hausmeiste...
# 11  Sonst würde ich keinen Aushilfslehrer suchen.\...
# 12  Ich steck dir deine Faust so tief in den Arsch...
# 13  Du Arschloch, ey.\nIch steck dir deine Faust s...
# 14  Ständig läuft hier einer Amok.\nEy, ich hab ei...
# 15  Was? Fick deine Mutter!\n(Durchsage) Amokalarm...
# 16  Na ja...\nKönnen Sie denn Glühbirnen austausch...
# 17  Nur kurz, Frau Gerster, die 10b...\nJetzt nich...
# 18  Ich grabe mich durch den Heizungskeller. Das s...
# 19  Alles klar. Weiß Bescheid. Kann ich so lange b...
# 20  Kleiner Vorgeschmack, wenn's länger dauert.\nA...
# 21  In ein, zwei Wochen hab ich das Geld von meine...
# 22  Vielleicht kann man die ja noch anheben. Mit '...
# 23  Ich hab ja nur 13 Monate auf diesen Scheißmome...
# 24  Da war nur so 'ne Baustelle. - Ach, wirklich?\...
# 25  Sag mal, will die mich verarschen?\nIch steh d...
# 26  Sag mal, will die mich verarschen?\nIch steh d...
# 27  Fuck.\nSag mal, will die mich verarschen?\nIch...
# 28  Charlie hier. Du, ich muss schnell machen.\nÜb...
# 29  Und eine? Die linke? Die ist irgendwie kleiner...
# 30  Du, Zeki, krieg ich von dem Geld neue Titten?\...
# 31  Du, Zeki, krieg ich von dem Geld neue Titten?\...
# 32  Bis zur Achten oder Neunten. Weiß nicht mehr, ...
# 33  Hier sind die Koordinaten, bei der Stecknadel....
# 34  Hier sind die Koordinaten, bei der Stecknadel....
# 35  Hier sind die Koordinaten, bei der Stecknadel....
# 36  Wo denn?\nHier sind die Koordinaten, bei der S...
# 37  Komm, heb dir das Gelutsche für deine Kundscha...
# 38  Komm, heb dir das Gelutsche für deine Kundscha...
# 39  Keine Ahnung, was kostet mich das?\nKomm, heb ...
# 40  Keine Ahnung, was kostet mich das?\nKomm, heb ...
# 41  Huhu, Baby!\nFreiheit!\nAlter, was hast du mit...
# 42  Alles Gute.\nObwohl Sie mit so wenig Allgemein...
# 43  Sie haben Ihren Hauptschulabschluss bestanden....
# 44  [lauter] ...dass Sie Ecstasy verkaufen.\n-Verp...
# 45  Mal angenommen, ich hätte das, was du suchst.\...
# 46  Hallo?\n[Ein Pferd wiehert.]\n[Mann] So, jetzt...
# 47  also in etwa einer Stunde.\n-Na ja, der geht h...
# 48  -Seitenstechen! -Arme hoch.\n-[Junge] Was 'ne ...
# 49  -[Moritz keucht.] -Scheint dir ja wichtig zu s...
# 50  Natürlich superintensive Zeit.\nLebensveränder...
# 51  Seit... seit wann trifft sich Lisa mit solchen...
# 52  Dan, der die halbe Schule mit Drogen versorgt....
# 53  Generation Z.\nJeder von uns hat das Gesamtwis...
# 54  Generation Z.\nJeder von uns hat das Gesamtwis...
# 55  ♪ And me ♪\n[Song geht verzerrt weiter.]\n[Mus...
# 56  Ist nichts drinnen.\n[Moritz] Ist alles okay?\...
# 57  -[Mann] So, junge Frau... -...die Verspätung.....
# 58  Ich wollte nur fragen, wann ich dir dein Gesch...
#
#                                   machine_translation  \
# 0   Deal. - Submit your documents.\nSee you asapis...
# 1   Alright, 2,200. but not really higher. We are ...
# 2   Salary is always good. - You are not a civil s...
# 3   Salary?\nSalary is always good. - You are not ...
# 4   Can I get a universal key? - Strange question,...
# 5   I sketched the new gym. The architect was comp...
# 6   Until then we have to lend a hand ourselves.\n...
# 7   My budget goes on the administration of crimin...
# 8   My budget goes on the administration of crimin...
# 9   The janitor had a heart attack. and we do not ...
# 10  Mr Müller. zeki miller.\nThe janitor had a hea...
# 11  Otherwise I wouldn't be looking for a substitu...
# 12  I'll stick your fist so deep in your ass,\ntha...
# 13  You asshole, ey.\nI'll stick your fist so deep...
# 14  Constantly running amok here.\nHey, I heard a ...
# 15  What? Fuck your mother!\n(Announcement) Amokal...
# 16  Well...\nCan you replace bulbs? Did you do the...
# 17  Just briefly, Mrs. Gerster, the 10b...\nNot no...
# 18  I dig through the boiler room. That's seven me...
# 19  All right. Know. Can I stay with you for so lo...
# 20  Little taste, if it takes longer.\nAll right. ...
# 21  In a week or two I'll have the money from my b...
# 22  Maybe you can raise that yet. With a ... crane...
# 23  I only waited 13 months for this fucking momen...
# 24  It was just a construction site. - Oh really?\...
# 25  Tell me, is she kidding me?\nI'm not into it. ...
# 26  Tell me, is she kidding me?\nI'm not into it. ...
# 27  Fuck.\nTell me, is she kidding me?\nI'm not in...
# 28  Charlie here. You, I have to do it fast.\nDo y...
# 29  And a? The left? It is somehow smaller.\nSerio...
# 30  You, Zeki, do I get new tits from the money?\n...
# 31  You, Zeki, do I get new tits from the money?\n...
# 32  Until the eighth or ninth. Do not remember, it...
# 33  Here are the coordinates, at the pin.\nI thoug...
# 34  Here are the coordinates, at the pin.\nI thoug...
# 35  Here are the coordinates, at the pin.\nI thoug...
# 36  Where?\nHere are the coordinates, at the pin.\...
# 37  Come, save the gossip for your clientele.\nWhe...
# 38  Come, save the gossip for your clientele.\nWhe...
# 39  I don't know, how much does it cost me?\nCome,...
# 40  I don't know, how much does it cost me?\nCome,...
# 41  Huhu, baby!\nFreedom!\nDude, what did you do w...
# 42  Alles Gute.\nObwohl Sie mit so wenig Allgemein...
# 43  Sie haben Ihren Hauptschulabschluss bestanden....
# 44  [loudly]...that you sell ecstasy.\n- Fuck you....
# 45  Let's say I had what you're looking for.\nGive...
# 46  Hello?\n[A horse whistles.]\n[Man] All right, ...
# 47  so in about an hour.\n-Well, he's going horseb...
# 48  -Stitch! -Arms up.\n-[Boy] What a pussy! -Hey,...
# 49  -[Moritz gasps.] -Seems to be important to you...
# 50  Super-intensive time, of course.\nLife-changin...
# 51  從那以後......麗莎什麼時候和這樣的傢伙見面？\n高大，美觀，受歡迎。 不是她的戰利品計...
# 52         丹，為一半的學校提供毒品。\nMelanie的兄弟與乳房。\n你知道梅蘭妮的乳房嗎？
# 53                 Z世代。\n我們每個人都擁有口袋裡的人性知識。\n可以通過點擊著名，
# 54                 Z世代。\n我們每個人都擁有口袋裡的人性知識。\n可以通過點擊著名，
# 55                             ♪和我♪\n[宋繼續扭曲。]\n[音樂停止。
# 56             裡面什麼都沒有。\n[莫里茨]一切都好嗎？\n我想和你討論這件事......
# 57   -  [男子]所以，年輕女人......  -  ......延遲......\n-Wai...
# 58  我只是想問我什麼時候可以給你你的禮物。\n莫里茨，連接不好。我們以後要不要和平交談？\n等。...
#
#                                     human_translation               first_jpg  \
# 0                                                 NaN  1700929572229_prev.jpg
# 1                                                 NaN  1700929563563_prev.jpg
# 2                                                 NaN  1700929540271_prev.jpg
# 3                                                 NaN  1700929525256_prev.jpg
# 4                                                 NaN  1700929513890_prev.jpg
# 5                                                 NaN  1700929501882_prev.jpg
# 6                                                 NaN  1700929487412_prev.jpg
# 7                                                 NaN  1700929470872_prev.jpg
# 8                                                 NaN  1700929467829_prev.jpg
# 9                                                 NaN  1700929458746_prev.jpg
# 10                                                NaN  1700929446736_prev.jpg
# 11                                                NaN  1700929432099_prev.jpg
# 12                                                NaN  1700929378489_prev.jpg
# 13                                                NaN  1700929371531_prev.jpg
# 14                                                NaN  1700929324354_prev.jpg
# 15                                                NaN  1700929310307_prev.jpg
# 16                                                NaN  1700929282192_prev.jpg
# 17                                                NaN  1700929215229_prev.jpg
# 18                                                NaN  1700929083260_prev.jpg
# 19                                                NaN  1700928982432_prev.jpg
# 20                                                NaN  1700928962477_prev.jpg
# 21                                                NaN  1700928950506_prev.jpg
# 22                                                NaN  1700928908608_prev.jpg
# 23                                                NaN  1700928898324_prev.jpg
# 24                                                NaN  1700928878233_prev.jpg
# 25                                                NaN  1700928849398_prev.jpg
# 26                                                NaN  1700928835354_prev.jpg
# 27                                                NaN  1700928820749_prev.jpg
# 28                                                NaN  1700928800513_prev.jpg
# 29                                                NaN  1700928768210_prev.jpg
# 30                                                NaN  1700928749532_prev.jpg
# 31                                                NaN  1700928745649_prev.jpg
# 32                                                NaN  1700928737424_prev.jpg
# 33                                                NaN  1700928687365_prev.jpg
# 34                                                NaN  1700928674124_prev.jpg
# 35                                                NaN  1700928666197_prev.jpg
# 36                                                NaN  1700928655737_prev.jpg
# 37                                                NaN  1700928625692_prev.jpg
# 38                                                NaN  1700928603010_prev.jpg
# 39                                                NaN  1700928572860_prev.jpg
# 40                                                NaN  1700928569465_prev.jpg
# 41                                                NaN  1700928512666_prev.jpg
# 42  Alles Gute.\nObwohl Sie mit so wenig Allgemein...  1700928375628_prev.jpg
# 43  Sie haben Ihren Hauptschulabschluss bestanden....  1700928357238_prev.jpg
# 44  That you sell ecstasy.\n-Fuck off. -Yeah, okay...  1697119781613_prev.jpg
# 45  Let's just say I had what you want.\nGive me o...  1697119743132_prev.jpg
# 46                                                NaN  1697119649262_prev.jpg
# 47  for about one hour.\n-Maybe he goes riding her...  1697119480441_prev.jpg
# 48  -I have a cramp! -Lift your arms.\n-What a pus...  1697119400651_prev.jpg
# 49  I guess it really is important to you.\n-I hav...  1697119370694_prev.jpg
# 50  Of course he did. Super intense time.\nLife-ch...  1697118610478_prev.jpg
# 51  ‎麗莎什麼時候開始跟那種人鬼混的？\n‎高大英俊，高人氣 ‎對，確實不是她的菜 ‎沒錯\n‎...  1697118502683_prev.jpg
# 52           ‎學校一半的人都是跟他買毒品\n‎那個波霸梅蘭妮的哥哥\n‎你知道波霸梅蘭妮吧？  1697118438553_prev.jpg
# 53           ‎Z世代\n‎這世代每個人的口袋裡 ‎都有完整的人類知識\n‎窩在臥室用手指一點  1697118032478_prev.jpg
# 54           ‎Z世代\n‎這世代每個人的口袋裡 ‎都有完整的人類知識\n‎窩在臥室用手指一點  1697118026789_prev.jpg
# 55                                                NaN  1697117916662_prev.jpg
# 56                 ‎裡面什麼都沒有\n‎一切都好吧？\n‎我本來想晚點再當面說，不過…  1697117807456_prev.jpg
# 57       ‎-小姐… ‎-…班機延誤了 ‎-我想… ‎-等一下\n‎這裡面也要檢查\n‎要看就看吧  1697117795582_prev.jpg
# 58  ‎我只是想問歡迎妳回來的禮物 ‎何時能拿給妳？\n‎莫賀茲，訊號不太穩 ‎可以晚點再聊嗎？\...  1697117777390_prev.jpg
#
#                 second_jpg              audio
# 0   1700929572229_next.jpg  1700929572229.mp3
# 1   1700929563563_next.jpg  1700929563563.mp3
# 2   1700929540271_next.jpg  1700929540271.mp3
# 3   1700929525256_next.jpg  1700929525256.mp3
# 4   1700929513890_next.jpg  1700929513890.mp3
# 5   1700929501882_next.jpg  1700929501882.mp3
# 6   1700929487412_next.jpg  1700929487412.mp3
# 7   1700929470872_next.jpg  1700929470872.mp3
# 8   1700929467829_next.jpg  1700929467829.mp3
# 9   1700929458746_next.jpg  1700929458746.mp3
# 10  1700929446736_next.jpg  1700929446736.mp3
# 11  1700929432099_next.jpg  1700929432099.mp3
# 12  1700929378489_next.jpg  1700929378489.mp3
# 13  1700929371531_next.jpg  1700929371531.mp3
# 14  1700929324354_next.jpg  1700929324354.mp3
# 15  1700929310307_next.jpg  1700929310307.mp3
# 16  1700929282192_next.jpg  1700929282192.mp3
# 17  1700929215229_next.jpg  1700929215229.mp3
# 18  1700929083260_next.jpg  1700929083260.mp3
# 19  1700928982432_next.jpg  1700928982432.mp3
# 20  1700928962477_next.jpg  1700928962477.mp3
# 21  1700928950506_next.jpg  1700928950506.mp3
# 22  1700928908608_next.jpg  1700928908608.mp3
# 23  1700928898324_next.jpg  1700928898324.mp3
# 24  1700928878233_next.jpg  1700928878233.mp3
# 25  1700928849398_next.jpg  1700928849398.mp3
# 26  1700928835354_next.jpg  1700928835354.mp3
# 27  1700928820749_next.jpg  1700928820749.mp3
# 28  1700928800513_next.jpg  1700928800513.mp3
# 29  1700928768210_next.jpg  1700928768210.mp3
# 30  1700928749532_next.jpg  1700928749532.mp3
# 31  1700928745649_next.jpg  1700928745649.mp3
# 32  1700928737424_next.jpg  1700928737424.mp3
# 33  1700928687365_next.jpg  1700928687365.mp3
# 34  1700928674124_next.jpg  1700928674124.mp3
# 35  1700928666197_next.jpg  1700928666197.mp3
# 36  1700928655737_next.jpg  1700928655737.mp3
# 37  1700928625692_next.jpg  1700928625692.mp3
# 38  1700928603010_next.jpg  1700928603010.mp3
# 39  1700928572860_next.jpg  1700928572860.mp3
# 40  1700928569465_next.jpg  1700928569465.mp3
# 41  1700928512666_next.jpg  1700928512666.mp3
# 42  1700928375628_next.jpg  1700928375628.mp3
# 43  1700928357238_next.jpg  1700928357238.mp3
# 44  1697119781613_next.jpg  1697119781613.mp3
# 45  1697119743132_next.jpg  1697119743132.mp3
# 46  1697119649262_next.jpg  1697119649262.mp3
# 47  1697119480441_next.jpg  1697119480441.mp3
# 48  1697119400651_next.jpg  1697119400651.mp3
# 49  1697119370694_next.jpg  1697119370694.mp3
# 50  1697118610478_next.jpg  1697118610478.mp3
# 51  1697118502683_next.jpg  1697118502683.mp3
# 52  1697118438553_next.jpg  1697118438553.mp3
# 53  1697118032478_next.jpg  1697118032478.mp3
# 54  1697118026789_next.jpg  1697118026789.mp3
# 55  1697117916662_next.jpg  1697117916662.mp3
# 56  1697117807456_next.jpg  1697117807456.mp3
# 57  1697117795582_next.jpg  1697117795582.mp3
# 58  1697117777390_next.jpg  1697117777390.mp3  >

# %% [markdown]
# # First of all: SYNONYMS!

# %%
if include_synonyms == True: 
    df['synonyms'] = ''
    def findSynonyms(lang, stem, usage):
        if lang == "en":
            language = "english"
        if lang == "it":
            language = "italian"
        if lang == "fr":
            language = "french"
        if lang == "ja":
            language = "japanese"
            
        #if not synonyms:
        messages = [        
            {"role": "user", "content": f"Provide me with two synonyms for '{stem}' in {language} that truly match\
            the meaning of '{stem}' in '{usage}'.\
            If there is no synonym, that fits the meaning of '{stem}' in the context of '{usage}', you can provide with a short description of '{stem}' instead.\
            Provide the synonyms always separated with a comma inbetween.\
            Don't repeat '{stem}' or 'synonym: 'at the beginning of your answer and don't put numbers or bullet points before the synonyms you return\
            Use a maximum of {max_words} words for each synonym."}
        ]

        response = openai.ChatCompletion.create(
            model=model,
            messages=messages,
            max_tokens=max_tokens,
            #temperature=0.5
        )
        
        synonyms = response.choices[0].message["content"]
        print(synonyms) 
        
        return synonyms

    df["synonyms"] = df.apply(lambda row: findSynonyms(row["lang"], row["stem"], row["long_phrase"]), axis=1)

# %%
if native_language_include_synonyms == True: 
    df['synonyms'] = ''
    def native_language_findSynonyms(stem, usage):
        #if not synonyms:
        messages = [        
            {"role": "user", "content": f"Provide me with two synonyms for '{stem}' in {native_language} that truly match\
            the meaning of '{stem}' in '{usage}'.\
            If there is no synonym, that fits the meaning of '{stem}' in the context of '{usage}', you can provide with a short description of '{stem}' instead.\
            Provide the synonyms always separated with a comma inbetween.\
            Don't repeat '{stem}' or 'synonym: 'at the beginning of your answer and don't put numbers or bullet points before the synonyms you return\
            Use a maximum of {max_words} words for each synonym."}
        ]

        response = openai.ChatCompletion.create(
            model=model,
            messages=messages,
            max_tokens=max_tokens,
            #temperature=0.5
        )
        
        synonyms = response.choices[0].message["content"]
        print(stem, "   :", synonyms) 
        
        return synonyms

    df["synonyms"] = df.apply(lambda row: native_language_findSynonyms(row["stem"], row["long_phrase"]), axis=1)
# Out:
# asapissimo    : pronto, immediately
# Unterlage    : documents, paperwork
# Brutto    : gross, before taxes
# verbeamten    : tenure, civil servant status
# Gehalt    : salary, income
# merkwürdige    : odd, peculiar
# inkompetent    : inept, unqualified
# Turnhalle    : gymnasium, sports hall
# Kabelbrand    : electrical fire, wire fire
# Strafanzeige    : criminal complaints, police reports
# Herzinfarkt    : myocardial infarction, heart attack
# fahl    : pallid, lackluster
# kratzen    : scratch, itch
# Faust    : fist, clenched hand
# beeilen    : hurry, hasten
# begeben    : proceed, move
# Glühbirnen    : incandescent bulbs, light bulbs
# Mistviecher    : brats, pests
# bescheuert    : ridiculous, absurd
# Schlankheitsfarm    : weight loss clinic, slimming spa
# pennen    : crash, sleep over
# Vorgeschmack    : foretaste, preview
# schuldest    : owe, are indebted
# anheben    : raise, hoist
# verlegen    : install, lay
# Glitter    : sparkle, shimmer
# Arschritze    : butt crack, gluteal cleft
# verarschen    : mock, fool
# übernimmst    : take over, cover for
# ernsthaft    : seriously, for real
# hup    : horn, car horn
# fresse    : shut up, be quiet
# Titte    : breast, boob
# Arsch    : soul, person
# Schulhof    : schoolyard, playground
# gucken    : look, watch
# Stecknadel    : pin, needle
# Kohle    : cash, dough
# vergraben    : buried, stashed
# Gelutsche    : sweet talk, schmoozing
# heb    : save, keep
# Freiheit    : liberty, freedom
# Allgemeinbildung    : general knowledge, general education
# Farce    : mockery, sham
# verpiss    : scram, buzz off
# nenn    : give, tell
# wiehert    : whinnies, neighs
# reiten    : horseback riding, equestrianism
# pimmel    : dick, cock
# Seitenstechen    : side stitch, side cramp
# lebensverändernd    : life-changing, transformative
# beuteschema    : "type," "taste"
# brüsten    : bosom, breasts
# hosentasche    : pocket, trouser pocket
# Gesamtwisse    : collective knowledge, total human knowledge
# verzerren    : distort, warp
# okay    : fine, all right
# auch    : too, as well
# schlecht    : poor, bad

# %% [markdown]
# # hint

# %%
if include_hint == True: 
    df['hint'] = ''
    def create_hint(lang, synonyms, word, stem, usage):
        length = len(usage.split())
        # print(length)
        max_tokens = int(150 + length + 0.33 * length)
        max_words = 8
        if lang == "en":
        #if not synonyms:
            messages = [
                {"role": "user", "content": 
                f"Provide me with a brief explanation of '{word}'. You can also take in account the context of '{stem}' in '{usage}'.\
                Be very concise, use a maximum of {max_words} words!\
                Return the explanation in the form '{word}: explanation.'."}
            ]

        if lang == "fr": 
            messages = [
                {"role": "user", "content": 
                f"Fournissez-moi une brève explication de {word}'\
                Vous pouvez également tenir compte du contexte de '{stem}' dans '{usage}'.\
                Soyez très concis, utilisez un maximum de {max_words} mots ! Je veux que l'explication soit différente de '{synonyms}'.\
                Renvoyez l'explication sous la forme '{word} : explication."}
            ]

        if lang == "it": 
            messages = [
                {"role": "user", "content": 
                f"Fornisci una breve spiegazione di '{word}'.\
                Si può anche prendere in considerazione il contesto di '{stem}' in '{usage}'.\
                Siate molto concisi, usare un massimo di {max_words} parole!\
                Restituire la spiegazione nella forma '{word}: spiegazione.'"}
            ]

        if lang == "ja": 
            messages = [
                {"role": "user", "content": 
                f"'{word}'の簡単な説明を提供してください。また、'{usage}'における'{stem}'の文脈を考慮することもできます。\
                非常に簡潔に表現し、最大で{max_words}単語を使用してください。\
                説明は'{word}：説明。'の形式で提供してください."}
            ]
            
        response = openai.ChatCompletion.create(
            model=model,
            messages=messages,
            max_tokens=max_tokens,
            #temperature=0.5
        )
        
        hint = response.choices[0].message["content"]
        print(hint) 
        
        return hint

    df["hint"] = df.apply(lambda row: create_hint(row["lang"], row["synonyms"], row["word"], row["stem"], row["long_phrase"]), axis=1)

# %% [markdown]
# # native Language hint

# %%
if native_language_include_hint == True: 
    df['hint'] = ''
    def create_hint(synonyms, word, stem, usage):
        length = len(usage.split())
        # print(length)
        max_tokens = int(150 + length + 0.33 * length)
        max_words = 8
        if native_language == "english":
        #if not synonyms:
            messages = [
                {"role": "user", "content": 
                f"Provide me with a brief explanation of '{word}'. You can also take in account the context of '{stem}' in '{usage}'.\
                Be very concise, use a maximum of {max_words} words!\
                Return the explanation in the form '{word}: explanation.'."}
            ]
        
        if native_language == "turkish":
        #if not synonyms:
            messages = [
                {"role": "user", "content": 
                f"'{word}' kelimesinin kısa bir açıklamasını sağla. \
                    Ayrıca, '{usage}' içinde '{stem}' bağlamını da dikkate alabilirsin. \
                    Çok özlü ol, en fazla {max_words} kelime kullan!\
                    Açıklamayı '{word}: açıklama.' şeklinde döndür."}
            ]

        if native_language == "french": 
            messages = [
                {"role": "user", "content": 
                f"Fournissez-moi une brève explication de {word}'\
                Vous pouvez également tenir compte du contexte de '{stem}' dans '{usage}'.\
                Soyez très concis, utilisez un maximum de {max_words} mots ! Je veux que l'explication soit différente de '{synonyms}'.\
                Renvoyez l'explication sous la forme '{word} : explication."}
            ]

        if native_language == "italian": 
            messages = [
                {"role": "user", "content": 
                f"Fornisci una breve spiegazione di '{word}'.\
                Si può anche prendere in considerazione il contesto di '{stem}' in '{usage}'.\
                Siate molto concisi, usare un massimo di {max_words} parole!\
                Restituire la spiegazione nella forma '{word}: spiegazione.'"}
            ]

        if native_language == "japanese": 
            messages = [
                {"role": "user", "content": 
                f"'{word}'の簡単な説明を提供してください。また、'{usage}'における'{stem}'の文脈を考慮することもできます。\
                非常に簡潔に表現し、最大で{max_words}単語を使用してください。\
                説明は'{word}：説明。'の形式で提供してください."}
            ]
            
        response = openai.ChatCompletion.create(
            model=model,
            messages=messages,
            max_tokens=max_tokens,
            #temperature=0.5
        )
        
        hint = response.choices[0].message["content"]
        print(hint) 
        
        return hint

    df["hint"] = df.apply(lambda row: create_hint(row["synonyms"], row["word"], row["stem"], row["long_phrase"]), axis=1)
# Out:
# asapissimo: extremely urgent, ASAP intensified.
# Unterlagen: Documents required, to be submitted later.
# Brutto: Gross amount before deductions like taxes.
# verbeamtet: granted civil servant status.
# Gehalt: Usually means "salary" in German.
# Merkwürdige: "Strange" or "peculiar" in context.
# inkompetent: lacking necessary skills or knowledge.
# Turnhalle: Sports or gymnasium hall.
# Kabelbrand: electrical cable fire or malfunction.
# Strafanzeigen: formal criminal complaints or reports.
# Herzinfarkt: German for heart attack.
# fahlen: having a pallid, negative connotation.
# kratzen: German for 'scratch'.
# Faust: A symbol for force or violent threat.
# beeilt: imperative of 'hurry up'.
# begeben: to proceed, go to a place.
# Glühbirnen: German for lightbulbs, electric bulbs for illumination.
# Mistviecher: colloquial, derogatory for animals/pests.
# bescheuert: foolish or senseless.
# Schlankheitsfarm: weight loss retreat or slimming spa.
# pennen: German slang for sleeping or crashing.
# Vorgeschmack: A small preview or taste of something.
# schuldest: you owe (used in debt context).
# anheben: to lift or raise something.
# verlegen: to install, e.g., pipes.
# Glitter: Sparkling decorative particles, hard to clean off.
# Arschritze: German for "butt crack.".
# verarschen: German for "to mock" or "to tease".
# Übernimmst: German for "Are you taking over".
# Ernsthaft: Seriously; expression of disbelief or earnest inquiry.
# Hupe: colloquial for car horn.
# Fresse: colloquial for "shut up" or "be quiet."
# Titten: German colloquial term for breasts.
# Arsch: German slang for "nobody" (in given context).
# Schulhof: German for schoolyard or school courtyard.
# guckt: colloquial German for "looks" or "watches".
# Stecknadel: Pin or marker (probably on a map).
# Kohle: Slang for "money" in German.
# vergraben: buried (money or object) for safekeeping.
# Gelutsche: meaningless or annoying talk, sweet-talking.
# heb: imperative of 'heben', meaning 'save' or 'keep'.
# Freiheit: German for "freedom" or "liberty".
# Allgemeinbildung: General knowledge or education.
# Farce: Mockery or sham, lacking serious intent.
# Verpiss: German slang for "go away."
# Nenn: Command form of 'to name.'
# wiehert: sound of horse neighing.
# reiten: to ride, typically a horse.
# Pimmel: German slang for penis.
# Seitenstechen: Side stitch, sharp pain in torso.
# Lebensverändernde: life-changing experiences.
# Beuteschema: Preferred partner characteristics.
# Brüsten: Likely refers to breasts (informal, possibly pejorative).
# Hosentasche: Pocket of trousers/pants.
# Gesamtwissen: collective human knowledge, accessible via technology.
# verzerrt: sound is distorted or altered.
# okay: Inquiry about well-being or situation.
# auch: also, too, as well.
# schlecht: poor quality, not good.

# %% [markdown]
# # include definition

# %%
if include_definition == True: 
    df['definition'] = ''
    def create_definition(lang, word, stem, usage):
        length = len(usage.split())
        # print(length)
        max_tokens = int(150 + length + 0.33 * length)
        max_words = 15
        if lang == "en":
        #if not synonyms:
            messages = [
                {"role": "user", "content": 
                f"Provide me with a dictionary like definition of '{word}'. You can also take in account the context of '{stem}' in '{usage}'.\
                Be very concise, use a maximum of {max_words} words!\
                Return the definition in the form '{word}: your definition.'."}
            ]

        if lang == "fr": 
            messages = [
                {"role": "user", "content": 
                f"Fournissez-moi une brève définition de '{word}' semblable à celle d'un dictionnaire.\
                Vous pouvez également tenir compte du contexte de '{stem}' dans '{usage}'.\
                Soyez très concis, utilisez un maximum de {max_words} mots !\
                Renvoyez la définition sous la forme '{word} : votre définition."}
            ]

        if lang == "it": 
            messages = [
                {"role": "user", "content": 
                f"Fornite una breve definizione da dizionario di '{word}' .\
                Si può anche prendere in considerazione il contesto di '{stem}' in '{usage}'.\
                Siate molto concisi, usare un massimo di {max_words} parole!\
                Restituire la definizione nella forma '{word}: la vostra definizione.'"}
            ]
        response = openai.ChatCompletion.create(
            model=model,
            messages=messages,
            max_tokens=max_tokens,
            #temperature=0.5
        )
        
        hint = response.choices[0].message["content"]
        print(hint) 
        
        return hint

    df["definition"] = df.apply(lambda row: create_definition(row["lang"], row["word"], row["stem"], row["long_phrase"]), axis=1)

# %% [markdown]
# # native_language definition

# %%
if native_language_include_definition == True: 
    df['definition'] = ''
    def create_definition(word, stem, usage, word_type):
        length = len(usage.split())
        # print(length)
        max_tokens = int(150 + length + 0.33 * length)
        max_words = 15
        if native_language == "english":
        #if not synonyms:
            messages = [
                {"role": "user", "content": 
                f"Provide me with a dictionary like definition of '{word}'. You can also take in account the context of '{stem}' in '{usage}'.\
                Be very concise, use a maximum of {max_words} words!\
                Return the definition in the form '{word}: your definition.'."}
            ]

        if native_language == "turkish":
            # instruction = ""
            # # if word_type == "Noun":
            # #     instruction = ""
            # # if word_type == "Adj":
            # if word_type == "Verb":
            #     instruction = "(sonsuz kip)"
        #if not synonyms:
            messages = [
                {"role": "user", "content": 
                f"'{word}' için sözlük tarzında bir tanım sağla. \
                    Ayrıca, '{usage}' içinde '{stem}' bağlamını da dikkate alabilirsin. \
                    Çok özlü ol, en fazla {max_words} kelime kullan!\
                    Tanımı '{word}: tanımınız.' şeklinde döndür."}
            ]

        if native_language == "french": 
            messages = [
                {"role": "user", "content": 
                f"Fournissez-moi une brève définition de '{word}' semblable à celle d'un dictionnaire.\
                Vous pouvez également tenir compte du contexte de '{stem}' dans '{usage}'.\
                Soyez très concis, utilisez un maximum de {max_words} mots !\
                Renvoyez la définition sous la forme '{word} : votre définition."}
            ]

        if native_language == "italian": 
            messages = [
                {"role": "user", "content": 
                f"Fornite una breve definizione da dizionario di '{word}' .\
                Si può anche prendere in considerazione il contesto di '{stem}' in '{usage}'.\
                Siate molto concisi, usare un massimo di {max_words} parole!\
                Restituire la definizione nella forma '{word}: la vostra definizione.'"}
            ]
        response = openai.ChatCompletion.create(
            model=model,
            messages=messages,
            max_tokens=max_tokens,
            #temperature=0.5
        )
        
        hint = response.choices[0].message["content"]
        print(hint) 
        
        return hint

    df["definition"] = df.apply(lambda row: create_definition(row["word"], row["stem"], row["long_phrase"], row["word_type"]), axis=1)
# Out:
# asapissimo: Extremely informal, exaggerated version of "as soon as possible," implying utmost urgency.
# Unterlagen: documents or paperwork required for a specific process or transaction.
# Brutto: Total income before deductions such as taxes and social security contributions.
# verbeamtet: holding the status of a civil servant, typically with employment benefits and job security.
# Gehalt: 1. Content, substance. 2. Salary, wages. (Context suggests the playful use of ambiguity.)
# Merkwürdige: adjective, meaning strange, odd, or peculiar in the given context.
# inkompetent: lacking the necessary skills or knowledge to perform effectively; unqualified.
# Turnhalle: Gymnasium or sports hall, often part of a school or community center.
# Kabelbrand: Electrical cable fire caused by short-circuiting or overheating.
# Strafanzeigen: Formal reports of criminal activities filed to the authorities.
# Herzinfarkt: Sudden blockage in coronary artery, causing heart muscle damage or death; myocardial infarction.
# fahlen: not possessing intensity; pallid or lacking in color or vitality.
# kratzen: to scratch or scrape, often causing an itch or irritation.
# Faust: Fist in German; context implies threat of violent insertion as punishment for tattling.
# beeilt: imperative form of "beeilen", meaning "hurry up" or "make haste".
# begeben: to proceed to, move toward or enter a place for safety or refuge.
# Glühbirnen: electric bulbs used for producing light, commonly replaceable by a maintenance person or homeowner.
# Mistviecher: German, derogatory for bothersome animals or figuratively, annoying persons/issues.
# bescheuert: foolish, stupid, or senseless.
# Schlankheitsfarm: A facility focused on weight loss, often offering dietary and fitness programs.
# pennen: (informal, German) to sleep, crash, or stay temporarily at a place.
# Vorgeschmack: A small preview or taste of what is to come.
# schuldest: second person singular present of "schulden," meaning owe or are indebted for.
# anheben: to lift or raise something; to increase or boost a value or amount.
# verlegen: to install or lay down, as in pipelines or cables.
# Glitter: Small, shiny particles for decoration, often lingering on skin and clothes.
# Arschritze: (German, vulgar) the crease or cleft between the buttocks; butt crack.
# verarschen: to mock, deceive, or make a fool of someone, often in a disrespectful way.
# Übernimmst: (verb) You take over; assume responsibility or control of something.
# Ernsthaft: Seriously; used to express genuine curiosity or disbelief.
# Hupe: (n., colloq.) car horn; slang for breast in certain contexts.
# Fresse: colloquial, impolite for mouth, often used to tell someone to be quiet or shut up.
# Titten: Colloquial German for breasts, often considered vulgar.
# Arsch: (German, slang) buttocks; used pejoratively to mean 'nobody' or 'no one' in colloquial contexts.
# Schulhof: area of a school's outdoor grounds, typically where students gather for recreation.
# guckt: (verb) informal German for "looks" or "watches", third person singular present of "gucken".
# Stecknadel: a pin often used as a marker on maps; figurative for precise location.
# Kohle: (colloquial, German) money, cash.
# vergraben: to bury something in the ground for concealment or safekeeping.
# Gelutsche: unnecessary, often insincere sweet talk or flattery, typically to manipulate or delay.
# heb: Informal, imperative form of "heben", German for "lift", "keep", or "save".
# Freiheit: The state of being free; absence of constraints; liberty.
# Allgemeinbildung: Broad general knowledge considered essential for informed social participation.
# Farce: a mockery, sham event lacking seriousness or value.
# Verpiss: German slang for "get lost" or "go away," used as a dismissive command.
# Nenn: imperative form of "nennen," meaning "to name" or "to call out".
# wiehert: (of a horse) emits a whinny or neighing sound.
# reiten: to ride a horse or engage in horseback riding.
# Pimmel: German slang for male genitalia, often considered vulgar.
# Seitenstechen: Transient sharp pain in the side, often experienced during vigorous exercise.
# Lebensverändernde: Experiences or events that significantly alter one's life.
# Beuteschema: Preferred type of partner or person of interest, typically in a romantic context.
# Brüsten: Colloquially, boasting or referring to prominent breasts in an informal context.
# Hosentasche: pocket in trousers for carrying small items, e.g., smartphone with internet access.
# Gesamtwissen: Total collective knowledge accessible, especially via technology.
# verzerrt: distorted, altered from original form, typically in a way that sounds unclear or unnatural.
# okay: Everything is satisfactory or acceptable; no problems or concerns.
# auch: also, as well, too, even (used to indicate inclusion or addition).
# schlecht: adverb or adjective; poor quality, bad, or unfavorable; here, referring to poor connection.

# %%
def createID(ID, source, date):
    newID = f"{ID}{source}{date}"
    newID = newID.replace(" ", "__")
    return newID
df["ID"] = df.apply(lambda row: createID(row["ID"], row["source"], row["date"]), axis=1)

def mp3_pattern(mp3):
        mp3 = "[sound:" + mp3 + "]"
        return mp3
df["audio"] = df.apply(lambda row: mp3_pattern(row["audio"]), axis=1)

def image(first_jpg, second_jpg):
    image = f'<img src="{first_jpg}"><img src="{second_jpg}">'
    return image
df["first_jpg"] = df.apply(lambda row: image(row["first_jpg"], row["second_jpg"]), axis=1)

# def clozePattern(word, phrase, translations):
#         word_new = f"{{c1::{word}::{translations}}}"
#         word_new = str(word_new)
#         #print(word_new)
#         phrase = phrase.replace(word, word_new)
#         return phrase
#         print(phrase)
# df["long_phrase"] = df.apply(lambda row: clozePattern(row["word"], row["long_phrase"], row["synonyms"]), axis=1)

import re

def clozePattern(word, phrase, translations):
    word_new = f"{{{{c1::{word}::{translations}}}}}"
    phrase = re.sub(rf'\b{word}\b', word_new, phrase, flags=re.IGNORECASE)
    return phrase

df["long_phrase"] = df.apply(lambda row: clozePattern(row["word"], row["long_phrase"], row["synonyms"]), axis=1)

def cleanHint(hint):
    # print(type(hint))
    if hint != "" and ":" in hint:
        parts = re.findall(r"[:](.+)?", hint) 
        # r"[:](.+)?" worked
        return f": {parts[0]}"
    else: 
        return ""
df["hint"] = df["hint"].apply(cleanHint)

# def definition_field(definition):
#       newDefinition = definition
#       return newDefinition
# df["definition"] = df.apply(lambda row: definition_field(row["word_translation"]), axis=1)

def notes_field(translation, word_translation):
    translation_str = str(translation) if not pd.isnull(translation) else ""
    word_translation_str = str(word_translation) if not pd.isnull(word_translation) else ""
    newNotes = translation_str + word_translation_str
    return newNotes

df["notes"] = df.apply(lambda row: notes_field(row["human_translation"], row["word_translation"]), axis=1)

# %%
ankiOut=df[['ID', 'long_phrase', 'hint', 'definition', 'first_jpg', 'audio', 'synonyms', 'notes']].copy()
ankiOut.columns = ['ID', 'cloze', 'hint', 'definition', 'image', 'audio', 'synonyms', 'notes']
# ankiOut.to_csv("/Users/moritzvitt/coding/anki.csv", sep=';', index=False, header=False)
ankiOut.to_csv("/Users/moritzvitt/coding/anki.csv", sep='\t', index=False)


df.to_excel("/Users/moritzvitt/coding/df.xlsx", index=False, header=False)
